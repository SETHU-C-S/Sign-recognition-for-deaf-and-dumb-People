# %%
import os
import cv2
import time
import uuid

IMAGE_PATH='CollectedImages'

labels=['Hello','Yes','No','Thanks','IloveYou','Please']

number_of_images=20

for label in labels:
    img_path = os.path.join(IMAGE_PATH, label)
    os.makedirs(img_path)
    cap=cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_of_images):
        ret,frame=cap.read()
        imagename=os.path.join(IMAGE_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imagename,frame)
        cv2.imshow('frame',frame)
        time.sleep(2)
        
        if cv2.waitKey(1) & 0xFF==ord('q'):
            break
    cap.release()
# Out:
# [ WARN:0@109.251] global /io/opencv/modules/videoio/src/cap_v4l.cpp (902) open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# Collecting images for Hello
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_2649/1705795559.py in <module>
#      19         ret,frame=cap.read()
#      20         imagename=os.path.join(IMAGE_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
# ---> 21         cv2.imwrite(imagename,frame)
#      22         cv2.imshow('frame',frame)
#      23         time.sleep(2)
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:801: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %%
import os
import cv2
import time
import uuid

IMAGE_PATH='CollectedImages'

labels=['Hello','Yes','No','Thanks','IloveYou','Please']

number_of_images=10

for label in labels:
    img_path = os.path.join(IMAGE_PATH, label)
    os.makedirs(img_path)
    cap=cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_of_images):
        ret,frame=cap.read()
        imagename=os.path.join(IMAGE_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imagename,frame)
        cv2.imshow('frame',frame)
        time.sleep(2)
        
        if cv2.waitKey(1) & 0xFF==ord('q'):
            break
    cap.release()
# Out:
# Collecting images for Hello
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
#
# QObject::moveToThread: Current thread (0x2ceb920) is not the object's thread (0x2ff2b50).
# Cannot move to target thread (0x2ceb920)
# Collecting images for Yes
# Collecting images for No
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2704/1747606652.py in <module>
#      15     cap=cv2.VideoCapture(0)
#      16     print('Collecting images for {}'.format(label))
# ---> 17     time.sleep(5)
#      18     for imgnum in range(number_of_images):
#      19         ret,frame=cap.read()
#
# KeyboardInterrupt:

# %%
import os
import cv2
import time
import uuid

IMAGE_PATH='CollectedImages'

labels=['Hello','Yes','No','Thanks','IloveYou','Please']

number_of_images=20

for label in labels:
    img_path = os.path.join(IMAGE_PATH, label)
    os.makedirs(img_path)
    cap=cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_of_images):
        ret,frame=cap.read()
        imagename=os.path.join(IMAGE_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imagename,frame)
        cv2.imshow('frame',frame)
        time.sleep(2)
        
        if cv2.waitKey(1) & 0xFF==ord('q'):
            break
    cap.release()
# Out:
# [ WARN:0@76.408] global /io/opencv/modules/videoio/src/cap_v4l.cpp (902) open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# Collecting images for Hello
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_2704/2766499924.py in <module>
#      19         ret,frame=cap.read()
#      20         imagename=os.path.join(IMAGE_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
# ---> 21         cv2.imwrite(imagename,frame)
#      22         cv2.imshow('frame',frame)
#      23         time.sleep(5)
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:801: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %%
import os
import cv2
import time
import uuid

IMAGE_PATH='CollectedImages'

labels=['Hello','Yes','No','Thanks','IloveYou','Please']

number_of_images=20

for label in labels:
    img_path = os.path.join(IMAGE_PATH, label)
    os.makedirs(img_path)
    cap=cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_of_images):
        ret,frame=cap.read()
        imagename=os.path.join(IMAGE_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imagename,frame)
        cv2.imshow('frame',frame)
        time.sleep(2)
        
        if cv2.waitKey(1) & 0xFF==ord('q'):
            break
    cap.release()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_2704/1705795559.py in <module>
#      12 for label in labels:
#      13     img_path = os.path.join(IMAGE_PATH, label)
# ---> 14     os.makedirs(img_path)
#      15     cap=cv2.VideoCapture(0)
#      16     print('Collecting images for {}'.format(label))
#
# ~/anaconda3/lib/python3.9/os.py in makedirs(name, mode, exist_ok)
#     223             return
#     224     try:
# --> 225         mkdir(name, mode)
#     226     except OSError:
#     227         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: 'CollectedImages/Hello'

# %%
import os
import cv2
import time
import uuid

IMAGE_PATH='CollectedImages'

labels=['Hello','Yes','No','Thanks','IloveYou','Please']

number_of_images=20

for label in labels:
    img_path = os.path.join(IMAGE_PATH, label)
    os.makedirs(img_path)
    cap=cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_of_images):
        ret,frame=cap.read()
        imagename=os.path.join(IMAGE_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imagename,frame)
        cv2.imshow('frame',frame)
        time.sleep(2)
        
        if cv2.waitKey(1) & 0xFF==ord('q'):
            break
    cap.release()
# Out:
# Collecting images for Hello
# Collecting images for Yes
# Collecting images for No
# Collecting images for Thanks
# Collecting images for IloveYou
# Collecting images for Please
